# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinavl3v3l/EVA6/blob/main/EVA6Session8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Jul 10 00:54:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
! pip install albumentations==0.4.6 -q

# %%
import albumentations
albumentations.__version__
# Out:
# '0.4.6'

# %% [markdown]
# # Image Classification on Cifar10 dataset.

# %%
# !git clone https://github.com/Abhinavl3v3l/EVA6.git
# %cd "EVA6/s8"
# !pwd
# Out:
# fatal: destination path 'EVA6' already exists and is not an empty directory.
# /content/EVA6/s8
# /content/EVA6/s8

# %% [markdown]
# ## Necessary packages

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchsummary import summary

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, utils
from torch.optim.lr_scheduler import ReduceLROnPlateau
import pickle
import numpy as np

# %%
from yadl.data.dataset import CIFAR10
from yadl.data.transform import albumentation_transform
from yadl.models import resnet
from yadl.utils.gradcam import gradcam, gradcam_utils
from yadl.utils.image_utilities import utils
from yadl.test import test
from yadl.train import train

# %% [markdown]
# ## Visualize data

# %%
viz_data = CIFAR10.cifar10(root='./data', train=True, download=True, transform=None)
classes = viz_data.classes
# Out:
# Files already downloaded and verified

# %%
print("Classes of CIFAR10 dataset", classes)
# Out:
# Classes of CIFAR10 dataset ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
print(utils.dataset_calculate_mean_std())
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ([0.24697121432552785, 0.24338893940435022, 0.2615925905215076], [0.4918687788500817, 0.4826539051649305, 0.44717727749693625])

# %%
mean=[0.4919, 0.4827, 0.4472]
stddev=[0.2470, 0.2434, 0.2616]

# %%
utils.visualize_data(viz_data,classes)

# %% [markdown]
# ## Prepare dataset, apply transform and prepare Dataloader

# %%
train_transform = albumentation_transform(train=True, mean=mean, stddev=stddev)
test_transform = albumentation_transform(train=False, mean=mean, stddev=stddev)

# %%
train_dataset = CIFAR10.cifar10(root='./data', train=True, download=True, transform=train_transform)
test_dataset = CIFAR10.cifar10(root='./data', train=False, download=True, transform=test_transform)
batch_size = 128
kwargs = {'num_workers': 2, 'pin_memory': True}
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, **kwargs)
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle = True, **kwargs)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
sample_images, sample_labels = next(iter(train_loader))
grid_image = torchvision.utils.make_grid(sample_images[:16], nrow=4, padding=1, pad_value=1)
print(grid_image.shape)
plt.imshow(grid_image.permute(1,2,0))
plt.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 133, 133])
# (-0.5, 132.5, 132.5, -0.5)

# %% [markdown]
# ## Model
#
# ### Network model creation and summary

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print("Available device:",device)
model = resnet.ResNet18('LayerNorm').to(device)
summary(model, input_size=(3, 32, 32))
# Out:
# Available device: cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#          GroupNorm-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#          GroupNorm-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#          GroupNorm-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#          GroupNorm-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#         GroupNorm-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#         GroupNorm-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#         GroupNorm-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#         GroupNorm-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#         GroupNorm-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#         GroupNorm-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#         GroupNorm-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#         GroupNorm-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#         GroupNorm-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#         GroupNorm-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#         GroupNorm-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#         GroupNorm-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#         GroupNorm-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------

# %% [markdown]
# ## Train model

# %%
EPOCHS = 40
train_accuracy = []
test_accuracy = []
train_loss = []
test_loss = []
l1_lambda=0
l2_lambda=0

# Optimization algorithm from torch.optim
optimizer = optim.SGD(model.parameters(), lr=0.03, momentum=0.9, weight_decay=l2_lambda)
# Loss condition
criterion = nn.CrossEntropyLoss()
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True, threshold=0.001, cooldown=0, min_lr=1e-4)

for epochs in range(EPOCHS):
    print(f"Epoch: {epochs}")
    train_acc_delta, train_loss_delta = train(model, device, train_loader, optimizer, criterion, l1_lambda)
    test_acc_delta, test_loss_delta = test(model, device, test_loader, criterion)
    scheduler.step(test_loss_delta)

    train_accuracy.append(round(train_acc_delta, 2))
    train_loss.append(round(train_loss_delta, 4))
    test_accuracy.append(round(test_acc_delta, 2))
    test_loss.append(round(test_loss_delta, 4))
# Out:
# Epoch: 0
# Train set: Epoch Accuracy: 27.16  Epoch Loss: 2.2558
# Test set: Epoch Accuracy: 31.08  Epoch Loss: 2.0283
# Epoch: 1
# Train set: Epoch Accuracy: 48.87  Epoch Loss: 1.3972
# Test set: Epoch Accuracy: 52.61  Epoch Loss: 1.3446
# Epoch: 2
# Train set: Epoch Accuracy: 60.79  Epoch Loss: 1.0952
# Test set: Epoch Accuracy: 57.3  Epoch Loss: 1.2138
# Epoch: 3
# Train set: Epoch Accuracy: 66.46  Epoch Loss: 0.9449
# Test set: Epoch Accuracy: 67.77  Epoch Loss: 0.9019
# Epoch: 4
# Train set: Epoch Accuracy: 70.01  Epoch Loss: 0.8452
# Test set: Epoch Accuracy: 60.96  Epoch Loss: 1.1763
# Epoch: 5
# Train set: Epoch Accuracy: 72.72  Epoch Loss: 0.7734
# Test set: Epoch Accuracy: 71.02  Epoch Loss: 0.8496
# Epoch: 6
# Train set: Epoch Accuracy: 74.71  Epoch Loss: 0.713
# Test set: Epoch Accuracy: 75.38  Epoch Loss: 0.6977
# Epoch: 7
# Train set: Epoch Accuracy: 76.86  Epoch Loss: 0.6587
# Test set: Epoch Accuracy: 75.16  Epoch Loss: 0.7187
# Epoch: 8
# Train set: Epoch Accuracy: 78.61  Epoch Loss: 0.6065
# Test set: Epoch Accuracy: 76.54  Epoch Loss: 0.6948
# Epoch: 9
# Train set: Epoch Accuracy: 80.16  Epoch Loss: 0.5661
# Test set: Epoch Accuracy: 79.3  Epoch Loss: 0.5867
# Epoch: 10
# Train set: Epoch Accuracy: 81.48  Epoch Loss: 0.5269
# Test set: Epoch Accuracy: 78.57  Epoch Loss: 0.617
# Epoch: 11
# Train set: Epoch Accuracy: 82.83  Epoch Loss: 0.49
# Test set: Epoch Accuracy: 80.72  Epoch Loss: 0.5555
# Epoch: 12
# Train set: Epoch Accuracy: 83.95  Epoch Loss: 0.4568
# Test set: Epoch Accuracy: 79.68  Epoch Loss: 0.6074
# Epoch: 13
# Train set: Epoch Accuracy: 85.07  Epoch Loss: 0.4318
# Test set: Epoch Accuracy: 81.33  Epoch Loss: 0.5529
# Epoch: 14
# Train set: Epoch Accuracy: 85.73  Epoch Loss: 0.4085
# Test set: Epoch Accuracy: 83.95  Epoch Loss: 0.4701
# Epoch: 15
# Train set: Epoch Accuracy: 86.58  Epoch Loss: 0.3835
# Test set: Epoch Accuracy: 82.87  Epoch Loss: 0.5242
# Epoch: 16
# Train set: Epoch Accuracy: 87.01  Epoch Loss: 0.3704
# Test set: Epoch Accuracy: 83.18  Epoch Loss: 0.4946
# Epoch: 17
# Train set: Epoch Accuracy: 88.09  Epoch Loss: 0.3444
# Test set: Epoch Accuracy: 82.6  Epoch Loss: 0.5146
# Epoch    18: reducing learning rate of group 0 to 3.0000e-03.
# Epoch: 18
# Train set: Epoch Accuracy: 91.26  Epoch Loss: 0.2552
# Test set: Epoch Accuracy: 88.82  Epoch Loss: 0.3326
# Epoch: 19
# Train set: Epoch Accuracy: 92.14  Epoch Loss: 0.2315
# Test set: Epoch Accuracy: 89.08  Epoch Loss: 0.3212
# Epoch: 20
# Train set: Epoch Accuracy: 92.31  Epoch Loss: 0.2249
# Test set: Epoch Accuracy: 89.18  Epoch Loss: 0.3244
# Epoch: 21
# Train set: Epoch Accuracy: 92.65  Epoch Loss: 0.2151
# Test set: Epoch Accuracy: 89.29  Epoch Loss: 0.3179
# Epoch: 22
# Train set: Epoch Accuracy: 92.72  Epoch Loss: 0.2103
# Test set: Epoch Accuracy: 89.27  Epoch Loss: 0.3176
# Epoch: 23
# Train set: Epoch Accuracy: 93.1  Epoch Loss: 0.204
# Test set: Epoch Accuracy: 89.47  Epoch Loss: 0.3143
# Epoch: 24
# Train set: Epoch Accuracy: 93.24  Epoch Loss: 0.1987
# Test set: Epoch Accuracy: 89.35  Epoch Loss: 0.3179
# Epoch: 25
# Train set: Epoch Accuracy: 93.28  Epoch Loss: 0.1929
# Test set: Epoch Accuracy: 89.6  Epoch Loss: 0.3151
# Epoch: 26
# Train set: Epoch Accuracy: 93.46  Epoch Loss: 0.1892
# Test set: Epoch Accuracy: 89.27  Epoch Loss: 0.3192
# Epoch    27: reducing learning rate of group 0 to 3.0000e-04.
# Epoch: 27
# Train set: Epoch Accuracy: 93.78  Epoch Loss: 0.1807
# Test set: Epoch Accuracy: 89.49  Epoch Loss: 0.3084
# Epoch: 28
# Train set: Epoch Accuracy: 93.97  Epoch Loss: 0.176
# Test set: Epoch Accuracy: 89.56  Epoch Loss: 0.3085
# Epoch: 29
# Train set: Epoch Accuracy: 93.78  Epoch Loss: 0.1792
# Test set: Epoch Accuracy: 89.57  Epoch Loss: 0.3083
# Epoch: 30
# Train set: Epoch Accuracy: 93.96  Epoch Loss: 0.1762
# Test set: Epoch Accuracy: 89.59  Epoch Loss: 0.3067
# Epoch: 31
# Train set: Epoch Accuracy: 94.02  Epoch Loss: 0.1757
# Test set: Epoch Accuracy: 89.66  Epoch Loss: 0.3061
# Epoch: 32
# Train set: Epoch Accuracy: 94.02  Epoch Loss: 0.1746
# Test set: Epoch Accuracy: 89.62  Epoch Loss: 0.3129
# Epoch: 33
# Train set: Epoch Accuracy: 94.03  Epoch Loss: 0.1733
# Test set: Epoch Accuracy: 89.53  Epoch Loss: 0.3129
# Epoch: 34
# Train set: Epoch Accuracy: 94.17  Epoch Loss: 0.1716
# Test set: Epoch Accuracy: 89.72  Epoch Loss: 0.3062
# Epoch    35: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 35
# Train set: Epoch Accuracy: 94.29  Epoch Loss: 0.1688
# Test set: Epoch Accuracy: 89.66  Epoch Loss: 0.3046
# Epoch: 36
# Train set: Epoch Accuracy: 94.14  Epoch Loss: 0.1705
# Test set: Epoch Accuracy: 89.56  Epoch Loss: 0.3042
# Epoch: 37
# Train set: Epoch Accuracy: 94.15  Epoch Loss: 0.1709
# Test set: Epoch Accuracy: 89.62  Epoch Loss: 0.308
# Epoch: 38
# Train set: Epoch Accuracy: 94.25  Epoch Loss: 0.1713
# Test set: Epoch Accuracy: 89.62  Epoch Loss: 0.3051
# Epoch: 39
# Train set: Epoch Accuracy: 94.05  Epoch Loss: 0.1711
# Test set: Epoch Accuracy: 89.57  Epoch Loss: 0.3049

# %% [markdown]
# ## Results
#
# ### Train/Test accuracy and loss versus epochs

# %%
utils.draw_loss_accuracy_graph(train_loss, test_loss, train_accuracy, test_accuracy)

# %% [markdown]
# ### Misclassified Images

# %%
label_incorrect, prediction_incorrect, \
images_incorrect = utils.capture_incorrect_classified_samples(model, device, test_loader)

# %%
denormalized_images = utils.denormalize(images_incorrect, mean, stddev)
utils.show_incorrect_images(label_incorrect, prediction_incorrect, denormalized_images, classes)

# %% [markdown]
# ## GradCAM on misclassified images

# %%
resnet_model_dict = dict(type='resnet', arch=model, layer_name='layer3', input_size=(32,32))
resnet_gradcam = gradcam.GradCAM(resnet_model_dict)

# %%
gradcam_utils.show_gradcam_images(resnet_gradcam, images_incorrect, label_incorrect, \
                    prediction_incorrect, classes, mean, stddev, device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:974: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3487: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
